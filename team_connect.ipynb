# %%
crime=pd.read_csv("C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/전국 범죄율 데이터.csv", encoding = 'euc-kr')
crime
report=pd.read_csv("C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/전국 범죄 신고율 데이터.csv", encoding = 'euc-kr')
report

report2=pd.read_csv("C:/Users/USERP/Downloads/몰루1.csv", encoding = 'euc-kr')
report2

sido2={'SGG행정구역별':[11, 21, 22, 23, 24, 25, 26, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39]}
sido2=pd.DataFrame(sido2)
sido={'행정구역별':[11, 21, 22, 23, 24, 25, 26, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39]}
sido=pd.DataFrame(sido)
total=pd.concat([sido,sido2, report, report2, crime], axis=1)
total.drop(columns=['행정구역별'], inplace=True)
sido2={'행정구역별':[11, 21, 22, 23, 24, 25, 26, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39]}
sido2=pd.DataFrame(sido2)
total=pd.concat([sido2, total], axis=1)
total
# Out:
#     행정구역별  SGG행정구역별     신고율     신고율  범죄율 대비 신고율
# 0      11        11  422293  422293       28727
# 1      21        21  155589  155589       10152
# 2      22        22  126122  126122        9013
# 3      23        23  160853  160853       10026
# 4      24        24   88990   88990        6068
# 5      25        25   82743   82743        6007
# 6      26        26   68512   68512        4322
# 7      29        29   27892   27892        1956
# 8      31        31  769744  769744       46568
# 9      32        32   75617   75617        6648
# 10     33        33   86709   86709        6675
# 11     34        34  122424  122424        9250
# 12     35        35   97731   97731        8179
# 13     36        36   94952   94952        8121
# 14     37        37  131374  131374       10257
# 15     38        38  194606  194606       13773
# 16     39        39   41068   41068        2840

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np
import pandas as pd
import folium
import webbrowser

# %%
#신고율, 범죄율 데이터, 행정구역 코드 데이터
crime=pd.read_csv("C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/전국 범죄율 데이터.csv", encoding = 'euc-kr')
report=pd.read_csv("C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/전국 범죄 신고율 데이터.csv", encoding = 'euc-kr')
SiDodf = pd.read_csv("C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_Ele_students_Teacher_ratio (1).csv", encoding = 'euc-kr')

# %%
#2011년 범죄율, 신고율 데이터 통합
crime_2011=pd.DataFrame([crime['2011']])
crime_2011=crime_2011.transpose()
report_2011=pd.DataFrame([report['2011']])
report_2011=report_2011.transpose()
df_2011=pd.concat([crime_2011, report_2011], axis=1)
new_columns = ['2011년 범죄율', '2011년 신고율']
df_2011.columns = new_columns
df_2011=df_2011['2011년 신고율']/df_2011['2011년 범죄율']
df_2011=pd.DataFrame([df_2011])
df_2011=df_2011.transpose()
df_2011=pd.concat([SiDodf, report_2011, crime_2011, df_2011], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2011.columns = new_columns

#2012년 범죄율, 신고율 데이터 통합
crime_2012=pd.DataFrame([crime['2012']])
crime_2012=crime_2012.transpose()
report_2012=pd.DataFrame([report['2012']])
report_2012=report_2012.transpose()
df_2012=pd.concat([crime_2012, report_2012], axis=1)
new_columns = ['2012년 범죄율', '2012년 신고율']
df_2012.columns = new_columns
df_2012=df_2012['2012년 신고율']/df_2012['2012년 범죄율']
df_2012=pd.DataFrame([df_2012])
df_2012=df_2012.transpose()
df_2012=pd.concat([SiDodf, report_2012, crime_2012, df_2012], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2012.columns = new_columns

#2013년 범죄율, 신고율 데이터 통합
crime_2013=pd.DataFrame([crime['2013']])
crime_2013=crime_2013.transpose()
report_2013=pd.DataFrame([report['2013']])
report_2013=report_2013.transpose()
df_2013=pd.concat([crime_2013, report_2013], axis=1)
new_columns = ['2013년 범죄율', '2013년 신고율']
df_2013.columns = new_columns
df_2013=df_2013['2013년 신고율']/df_2013['2013년 범죄율']
df_2013=pd.DataFrame([df_2013])
df_2013=df_2013.transpose()
df_2013=pd.concat([SiDodf, report_2013, crime_2013, df_2013], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2013.columns = new_columns

#2014년 범죄율, 신고율 데이터 통합
crime_2014=pd.DataFrame([crime['2014']])
crime_2014=crime_2014.transpose()
report_2014=pd.DataFrame([report['2014']])
report_2014=report_2014.transpose()
df_2014=pd.concat([crime_2014, report_2014], axis=1)
new_columns = ['2014년 범죄율', '2014년 신고율']
df_2014.columns = new_columns
df_2014=df_2014['2014년 신고율']/df_2014['2014년 범죄율']
df_2014=pd.DataFrame([df_2014])
df_2014=df_2014.transpose()
df_2014=pd.concat([SiDodf, report_2014, crime_2014, df_2014], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2014.columns = new_columns

#2015년 범죄율, 신고율 데이터 통합
crime_2015=pd.DataFrame([crime['2015']])
crime_2015=crime_2015.transpose()
report_2015=pd.DataFrame([report['2015']])
report_2015=report_2015.transpose()
df_2015=pd.concat([crime_2015, report_2015], axis=1)
new_columns = ['2015년 범죄율', '2015년 신고율']
df_2015.columns = new_columns
df_2015=df_2015['2015년 신고율']/df_2015['2015년 범죄율']
df_2015=pd.DataFrame([df_2015])
df_2015=df_2015.transpose()
df_2015=pd.concat([SiDodf, report_2015, crime_2015, df_2015], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2015.columns = new_columns

#2016년 범죄율, 신고율 데이터 통합
crime_2016=pd.DataFrame([crime['2016']])
crime_2016=crime_2016.transpose()
report_2016=pd.DataFrame([report['2016']])
report_2016=report_2016.transpose()
df_2016=pd.concat([crime_2016, report_2016], axis=1)
new_columns = ['2016년 범죄율', '2016년 신고율']
df_2016.columns = new_columns
df_2016=df_2016['2016년 신고율']/df_2016['2016년 범죄율']
df_2016=pd.DataFrame([df_2016])
df_2016=df_2016.transpose()
df_2016=pd.concat([SiDodf, report_2016, crime_2016, df_2016], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2016.columns = new_columns

#2017년 범죄율, 신고율 데이터 통합
crime_2017=pd.DataFrame([crime['2017']])
crime_2017=crime_2017.transpose()

report_2017=pd.DataFrame([report['2017']])
report_2017=report_2017.transpose()

df_2017=pd.concat([crime_2017, report_2017], axis=1)

new_columns = ['2017년 범죄율', '2017년 신고율']
df_2017.columns = new_columns
df_2017=df_2017['2017년 신고율']/df_2017['2017년 범죄율']
df_2017=pd.DataFrame([df_2017])
df_2017=df_2017.transpose()
df_2017=pd.concat([SiDodf, report_2017, crime_2017, df_2017], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2017.columns = new_columns

#2018년 범죄율, 신고율 데이터 통합
crime_2018=pd.DataFrame([crime['2018']])
crime_2018=crime_2018.transpose()

report_2018=pd.DataFrame([report['2018']])
report_2018=report_2018.transpose()

df_2018=pd.concat([crime_2018, report_2018], axis=1)

new_columns = ['2018년 범죄율', '2018년 신고율']
df_2018.columns = new_columns
df_2018=df_2018['2018년 신고율']/df_2018['2018년 범죄율']
df_2018=pd.DataFrame([df_2018])
df_2018=df_2018.transpose()
df_2018=pd.concat([SiDodf, report_2018, crime_2018, df_2018], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2018.columns = new_columns

#2019년 범죄율, 신고율 데이터 통합
crime_2019=pd.DataFrame([crime['2019']])
crime_2019=crime_2019.transpose()

report_2019=pd.DataFrame([report['2019']])
report_2019=report_2019.transpose()

df_2019=pd.concat([crime_2019, report_2019], axis=1)

new_columns = ['2019년 범죄율', '2019년 신고율']
df_2019.columns = new_columns
df_2019=df_2019['2019년 신고율']/df_2019['2019년 범죄율']
df_2019=pd.DataFrame([df_2019])
df_2019=df_2019.transpose()
df_2019=pd.concat([SiDodf, report_2019, crime_2019, df_2019], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2019.columns = new_columns

# %%
#2020년 범죄율, 신고율 데이터 통합
crime_2020=pd.DataFrame([crime['2020']])
crime_2020=crime_2020.transpose()

report_2020=pd.DataFrame([report['2020']])
report_2020=report_2020.transpose()

df_2020=pd.concat([crime_2020, report_2020], axis=1)

new_columns = ['2020년 범죄율', '2020년 신고율']
df_2020.columns = new_columns
df_2020=df_2020['2020년 신고율']/df_2020['2020년 범죄율']
df_2020=pd.DataFrame([df_2020])
df_2020=df_2020.transpose()
df_2020=pd.concat([SiDodf, report_2020, crime_2020, df_2020], axis=1)
new_columns = ['SGG행정구역별', '행정구역별', '신고율', '범죄율', '범죄율 대비 신고율']
df_2020.columns = new_columns

# %%
#그래프 그리기 위해 데이터 분리
crime_plt=crime.drop(columns='행정구역별')
report_plt=report.drop(columns='행정구역별')

# %%
#범죄율 데이터 그래프 변화
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.figure(figsize=(15,10))
plt.plot(crime_plt)
ticklabel=('2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020')

plt.xticks(np.arange(0, 18, 1.8), ticklabel)

title_font = {
    'fontsize': 30,
    'fontweight': 'bold'
}

plt.title('전국 범죄율 변화 추이', fontdict=title_font, loc='center', pad=20)
plt.legend(['경기','충북','충남','전북','전남','경북','경남','강원','제주','서울','울산','대전','부산','대구','인천','광주'],fontsize=22)

# %%
#신고율 데이터 그래프 변화
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.figure(figsize=(15,10))
plt.plot(report_plt)
ticklabel=('2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020')

plt.xticks(np.arange(0, 18, 1.8), ticklabel)

title_font = {
    'fontsize': 30,
    'fontweight': 'bold'
}

plt.title('전국 신고율 변화 추이', fontdict=title_font, loc='center', pad=20)
plt.legend(['경기','충북','충남','전북','전남','경북','경남','강원','제주','서울','울산','대전','부산','대구','인천','광주'],fontsize=22)

# %%
#2011년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2011 범죄율 대비 신고율',
        data=df_2011,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2011 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2012년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2012 범죄율 대비 신고율',
        data=df_2012,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2012 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2013년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2013 범죄율 대비 신고율',
        data=df_2013,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2013 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2014년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2014 범죄율 대비 신고율',
        data=df_2014,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2014 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2015년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2015 범죄율 대비 신고율',
        data=df_2015,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2015 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2016년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2016 범죄율 대비 신고율',
        data=df_2016,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2016 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2017년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2017 범죄율 대비 신고율',
        data=df_2017,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2017 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2018년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2018 범죄율 대비 신고율',
        data=df_2018,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2018 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2019년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2019 범죄율 대비 신고율',
        data=df_2019,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2019 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()

# %%
#2020년 데이터 시각화
def main():

    #시도별 범죄율, 신고율 통합 데이터 및 비율 데이터

    SiDo_geo = "C:/Users/USERP/Desktop/예측 코드- Python/빅데이터 분석 경진대회 - 커넥트팀/Si_Do_map_utf8.json"
 
    m = folium.Map(location=[36.45, 127.42], 
                   tiles="OpenStreetMap", zoom_start=8)


    folium.Choropleth(
        geo_data = SiDo_geo,
        name='2020 범죄율 대비 신고율',
        data=df_2020,
        columns=['행정구역별', '범죄율 대비 신고율'],
        key_on='feature.properties.CTP_KOR_NM',
        fill_color='PuRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='2020 범죄 대비 신고율').add_to(m)

    # 색칠한 layer 켜고 끄기 버튼 추가
    folium.LayerControl().add_to(m)
    
    m.save('map.html')
    webbrowser.open('map.html') 

# main 함수 로딩부
if __name__ == '__main__':
    main()
